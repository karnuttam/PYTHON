# %%
import numpy as np
l =[]
for i in range(1,5):
    int_1 = int(input("Enter: "))
    l.append(int_1)
print(np.array(l));
# Out:
# Enter:  45
# Enter:  44
# Enter:  45
# Enter:  78
# [45 44 45 78]
